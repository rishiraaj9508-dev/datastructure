# %% [raw]
#
#
# ### **1. What are data structures, and why are they important?**
#
# Organized methods for effectively managing, storing, and retrieving data are called data structures.  Lists, stacks, queues, trees, graphs, sets, and dictionaries are some examples.  They are crucial because they enhance processing speed, maximize memory utilization, and improve algorithm efficiency.  Program performance can be significantly enhanced by selecting the appropriate data structure, particularly when searching, sorting, indexing, and managing big datasets.  They also improve the organization, cleanliness, and maintainability of the code.
#
# ---
#
# ### **2. Difference between mutable and immutable data types with examples**
#
# Unlike immutable data types, mutable data types can be altered after they are created.  You can add, remove, or change elements in lists, dictionaries, and sets.  Integers, strings, and tuples are immutable; altering them results in a new object.  For example, modifying a list with `list.append()` changes the same object, but modifying a string like `s = s + "a"` creates a new string.  Immutability ensures safety, stability, and consistency, especially when data shouldn’t be altered.
#
# ---
#
# ### **3. Differences between lists and tuples in Python**
#
# Lists can have their elements changed, added, or removed because they are mutable.  They are more adaptable but slower.  Tuples are quicker and use less memory because, once created, their values cannot be altered.  Tuples use parentheses `( )`, whereas lists use square brackets `[ ]`.  Tuples are perfect for fixed collections like coordinates or database records because they cannot be changed.  When data requires dynamic behavior or updates, lists work best.  When tuples only contain immutable elements, hashing is also supported.
#
# ---
#
# ### **4. Describe how dictionaries store data**
#
# Dictionaries use an internal hash table to store data as key-value pairs.  An index is created by hashing each key, enabling incredibly quick lookup, insertion, and deletion.  The values are stored at the hashed positions, ensuring average O(1) access time.  Keys must be unique and immutable, while values can be any type.  Python handles collisions using techniques like open addressing.  This structure makes dictionaries ideal for tasks requiring fast searching or mapping relationships.
#
# ---
#
# ### **5. Why might you use a set instead of a list in Python?**
#
# A set is used when you want to store unique elements without duplicates. It also offers faster membership testing because it uses hashing, giving average O(1) lookup time, compared to O(n) in lists. Sets automatically remove duplicate values and are useful in tasks like removing repeated entries, finding intersections, unions, or differences. If ordering and indexing are not important, and you need fast lookups and uniqueness, a set is a better choice than a list.
# ---
#
# ### **6. What is a string in Python, and how is it different from a list?**
#
# A string is an immutable sequence of characters, while a list is a mutable sequence that can hold various data types. You cannot change characters inside a string directly, but you can modify list elements. Strings are optimized for text processing, support slicing, and don't allow structural changes. Lists allow append, insert, delete, and replace operations. Also, strings store only characters, whereas lists can store integers, strings, objects, or even nested lists.
#
# ---
#
# ### **7. How do tuples ensure data integrity in Python?**
#
# Tuples are immutable, meaning their data cannot be changed after creation. This immutability ensures that the stored values remain constant, protecting them from accidental modification. Because of this, tuples are ideal for fixed data like coordinates, dates, configuration settings, or records fetched from a database. Their immutability also allows them to be used as dictionary keys or set elements. Tuples ensure predictable behavior in applications where stability and reliability of stored data are important.
#
# ---
#
# ### **8. What is a hash table, and how does it relate to dictionaries in Python?**
#
# A hash table is a data structure that stores key-value pairs using a hash function to compute an index where the value is stored. Python dictionaries use hash tables internally. When a key is provided, it is hashed, and the result determines where the corresponding value is stored or retrieved. This gives extremely fast access time. Hashing also ensures keys are unique and immutable. Collisions are handled internally. That’s why dictionaries offer O(1) average lookup performance.
#
# ---
#
# ### **9. Can lists contain different data types in Python?**
#
# Yes, Python lists can store multiple data types within the same list. You can mix integers, floats, strings, booleans, other lists, tuples, objects, or even functions. This flexibility comes from Python being dynamically typed. Lists act as containers that do not restrict the type of elements they hold. This makes them suitable for diverse collections, quick prototyping, and real-world applications where different data types must be grouped together. However, mixed types may reduce efficiency in some algorithms.
#
# ---
#
# ### **10. Explain why strings are immutable in Python**
#
# Strings are immutable for reasons of security, performance, and memory optimization. Since strings are heavily used, immutability allows Python to safely store and reuse them without worrying about accidental modification. It also enables string interning, saving memory by reusing identical strings. Additionally, immutability makes strings thread-safe, preventing unexpected changes during execution. When a string is “modified,” Python creates a new one instead of changing the original, ensuring the original data remains consistent.
#
# ---
#
# ### **11. What advantages do dictionaries offer over lists for certain tasks?**
#
# Dictionaries provide fast O(1) average-time lookups using keys, while lists require scanning through elements, making them O(n). Dictionaries store data in key-value pairs, enabling quick retrieval based on meaningful identifiers instead of numeric indexes. They prevent duplicate keys and offer clearer, more readable code when mapping relationships—for example, storing student data by roll number or username. Dictionaries also allow flexible and dynamic data structures suited for configurations, databases, APIs, and structured information.
#
# ---
#
# ### **12. How do sets handle duplicate values in Python?**
#
# Sets automatically remove duplicate values because they store elements based on their hash values. When you insert an element, Python checks if an item with the same hash already exists. If yes, it is ignored; if not, it is added. This ensures all elements in a set remain unique. The hashing also gives sets fast O(1) membership testing. Sets are ideal for eliminating duplicates, performing mathematical operations like intersections, and efficiently checking whether an element exists.
#
# ---
#
# ### **13. Describe a scenario where using a tuple would be preferable over a list**
#
# A tuple is preferable when you need to store data that should not change, such as GPS coordinates, configuration values, database records, or fixed menu items. Because tuples are immutable, they ensure the data remains secure and unchanged inadvertently. They are faster and more memory efficient than lists, making them ideal for large fixed datasets. Tuples can also be used as keys in dictionaries, unlike lists, making them useful in mapping structured, unchangeable information.
#
# ---
#
# ### **14. How does the “in” keyword work differently for lists and dictionaries?**
#
# In lists, the `in` keyword checks whether a value exists among the elements, requiring a linear search with O(n) time complexity. For dictionaries, `in` checks only the keys, not the values, and does this using hashing, giving an average O(1) lookup time. So, `"a" in dict` checks if `"a"` is a key. For values, you'd use `"a" in dict.values()"`. Dictionaries are much faster due to hash-based indexing, while lists rely on scanning elements.
#
# ---
#
# ### **15. Can you modify the elements of a tuple? Explain why or why not**
#
# No, you cannot modify tuple elements because tuples are immutable. Once created, their contents cannot be changed, added, or removed. This design ensures data consistency, reliability, and hashability. If a tuple contains mutable objects like lists, those internal elements can change, but the tuple’s structure remains fixed. Immutability allows tuples to be used safely as dictionary keys and improves performance by preventing accidental modifications.
#
# ---
#
# ### **16. What is a nested dictionary, and give an example of its use case**
#
# A nested dictionary is a dictionary where each key maps to another dictionary, allowing multi-level data organization. It is useful for representing complex structured data like JSON, student records, or hierarchical systems. For example:
# `students = {"101": {"name": "Aman", "marks": 85}}`.
# This structure helps store related information together in an organized form. Nested dictionaries are often used in APIs, databases, and configuration files requiring multi-dimensional representation.
#
# ---
#
# ### **17. Describe the time complexity of accessing elements in a dictionary**
#
# Accessing elements in a dictionary has an average time complexity of **O(1)** due to its hash table implementation. The key is hashed, and the hash value directly maps to the location where the value is stored. However, in rare cases of hash collisions or poor hashing, the worst-case time complexity becomes **O(n)**. But Python optimizations make average O(1) lookup extremely reliable. This efficiency makes dictionaries ideal for fast lookups, caching, indexing, and mapping large datasets.
#
# ---
#
# ### **18. In what situations are lists preferred over dictionaries?**
#
# Lists are preferred when data must maintain order, when indexing by position is required, or when elements may repeat. They’re ideal for sequences, stacks, queues, matrix representations, and any situation involving iteration in a defined order. Lists also allow easy insertion, deletion, and sorting. If your data doesn’t require key-value mapping and indexing by number is sufficient, lists are simpler and more memory-efficient. They’re used extensively in algorithms, numerical operations, and general-purpose collections.
#
# ---
#
# ### **19. Why are dictionaries considered unordered, and how does that affect data retrieval?**
#
# Dictionaries are considered unordered because their internal structure is based on hashing, which does not maintain insertion order in older Python versions. Modern Python (3.7+) preserves insertion order, but the hash table still doesn't rely on sequential numbering like lists. This means data cannot be retrieved by numeric index—only by key. Retrieval depends entirely on the key’s hash, making dictionary access fast but non-position-based. Keys must be known to access values, unlike lists where indexing is possible.
#
# ---
#
# ### **20. Explain the difference between a list and a dictionary in terms of data retrieval**
#
# Lists retrieve data by index, meaning each element has a numeric position, giving efficient sequential storage but slower searches. Dictionaries retrieve data by key, providing fast O(1) average lookup using hashing. Lists are ideal for ordered data and iterations, while dictionaries are suitable for mapping relationships like name → phone number. Lists require scanning for value lookup, but dictionaries directly access the value through the key. Thus, dictionaries excel in fast searches and mapping tasks.
#
# ---

# %%
# 1. Write a code to create a string with your name and print it
name = "Rishi"
print(name)
# Out:
# Rishi

# %%
# 2. Write a code to find the length of the string "Hello World"
text = "Hello World"
print(len(text))
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from the string "Python Programming"
s = "Python Programming"
print(s[:3])
# Out:
# Pyt

# %%
# 4. Write a code to convert the string "hello" to uppercase
print("hello".upper())
# Out:
# HELLO

# %%
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"
s = "I like apple"
print(s.replace("apple", "orange"))
# Out:
# I like orange

# %%
# 6. Write a code to create a list with numbers 1 to 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4]
lst = [1, 2, 3, 4]
lst.append(10)
print(lst)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
lst = [1, 2, 3, 4, 5]
lst.remove(3)
print(lst)
# Out:
# [1, 2, 4, 5]

# %%
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']
letters = ['a', 'b', 'c', 'd']
print(letters[1])
# Out:
# b

# %%
# 10. Write a code to reverse the list [10, 20, 30, 40, 50]
lst = [10, 20, 30, 40, 50]
lst.reverse()
print(lst)
# 10. Write a code to reverse the list [10, 20, 30, 40, 50]
lst = [10, 20, 30, 40, 50]
lst.reverse()
print(lst)
# Out:
# [50, 40, 30, 20, 10]
# [50, 40, 30, 20, 10]

# %%
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it
t = (100, 200, 300)
print(t)
# Out:
# (100, 200, 300)

# %%
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15)
t = (10, 20, 5, 15)
print(min(t))
# Out:
# 5

# %%
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
t = ('dog', 'cat', 'rabbit')
print(t.index("cat"))
# Out:
# 1

# %%
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
fruits = ("mango", "apple", "banana")
print("kiwi" in fruits)
# Out:
# False

# %%
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it
s = {'a', 'b', 'c'}
print(s)
# Out:
# {'c', 'b', 'a'}

# %%
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
print({1, 2, 3} | {3, 4, 5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
print({1, 2, 3} & {2, 3, 4})
# Out:
# {2, 3}

# %%
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it
person = {"name": "ram", "age": 25, "city": "Delhi"}
print(person)
# Out:
# {'name': 'ram', 'age': 25, 'city': 'Delhi'}

# %%
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}
d = {'name': 'ram', 'age': 25}
d['country'] = 'USA'
print(d)
# Out:
# {'name': 'ram', 'age': 25, 'country': 'USA'}

# %%
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
d = {'name': 'Alice', 'age': 30}
print(d["name"])
# Out:
# Alice

# %%
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}
d = {'name': 'Bablu', 'age': 22, 'city': 'New York'}
d.pop("age")
print(d)
# Out:
# {'name': 'Bablu', 'city': 'New York'}

# %%
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
d = {'name': 'Alice', 'city': 'Paris'}
print("city" in d)
# Out:
# True

# %%
 # 26. Write a code to create a list, a tuple, and a dictionary, and print them all
lst = [1, 2, 3]
tpl = (4, 5, 6)
dic = {"a": 1, "b": 2}
print(lst, tpl, dic)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print it
import random
lst = [random.randint(1, 100) for _ in range(5)]
lst.sort()
print(lst)
# Out:
# [2, 12, 48, 81, 85]

# %%
# 28. Write a code to create a list with strings and print the element at the third index
lst = ["apple", "banana", "cherry", "mango", "kiwi"]
print(lst[3])
# Out:
# mango

# %%
# 29. Write a code to combine two dictionaries into one and print the result
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}
d3 = {**d1, **d2}
print(d3)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 30. Write a code to convert a list of strings into a set
lst = ["a", "b", "c", "a"]
print(set(lst))
# Out:
# {'c', 'b', 'a'}
